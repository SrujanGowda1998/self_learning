# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
plt.xlabel("Year")
plt.ylabel("Per Capita Income (US$)")
plt.scatter(df["year"], df["per capita income (US$)"], color="red", marker=".")

# %%
new_df = df.drop("per capita income (US$)", axis="columns")

# %%
new_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
income = df["per capita income (US$)"]
income.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df, income)
# Out:
# LinearRegression()

# %%
reg.predict([[2025]])
# Out:
# c:\Users\sruja\Desktop\JOB HUNT\Notes & Codes\Statistics & Machine Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %% [markdown]
# Y = mX + C
#
# m-coefficient
# C-intercept
